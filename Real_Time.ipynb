# %%
import os
import cv2
import imutils
import time
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from imutils.video import VideoStream
import tkinter as tk
from tkinter import filedialog
from tkinter import *
import sys

# %%
# Provide the correct path to the .caffemodel file
caffemodel_weights_Path = r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\face_detector\res10_300x300_ssd_iter_140000.caffemodel"

# Provide the correct path to the .prototxt file
txt_file_path = r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\face_detector\deploy.prototxt"

# Load the pre-trained model
Pretrain_face_detection_Model = cv2.dnn.readNet(txt_file_path, caffemodel_weights_Path)

# Our trained model for classification of mask and without mask
cls_model = load_model("MobileNet.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import math
import argparse

def highlightFace(net, frame, conf_threshold=0.7):
    frameOpencvDnn=frame.copy()
    frameHeight=frameOpencvDnn.shape[0]
    frameWidth=frameOpencvDnn.shape[1]
    blob=cv2.dnn.blobFromImage(frameOpencvDnn, 1.0, (300, 300), [104, 117, 123], True, False)

    net.setInput(blob)
    detections=net.forward()
    faceBoxes=[]
    for i in range(detections.shape[2]):
        confidence=detections[0,0,i,2]
        if confidence>conf_threshold:
            x1=int(detections[0,0,i,3]*frameWidth)
            y1=int(detections[0,0,i,4]*frameHeight)
            x2=int(detections[0,0,i,5]*frameWidth)
            y2=int(detections[0,0,i,6]*frameHeight)
            faceBoxes.append([x1,y1,x2,y2])
            cv2.rectangle(frameOpencvDnn, (x1,y1), (x2,y2), (0,255,0), int(round(frameHeight/150)), 8)
    return frameOpencvDnn,faceBoxes

faceProto=r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\gad\opencv_face_detector.pbtxt"
faceModel=r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\gad\opencv_face_detector_uint8.pb"
ageProto=r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\gad\age_deploy.prototxt"
ageModel=r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\gad\age_net.caffemodel"
genderProto=r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\gad\gender_deploy.prototxt"
genderModel=r"C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction\gad\gender_net.caffemodel"

MODEL_MEAN_VALUES=(78.4263377603, 87.7689143744, 114.895847746)
ageList=['(0-3)', '(4-7)', '(8-12)', '(13-20)', '(21-37)', '(38-47)', '(48-59)', '(60-100)']
genderList=['Male','Female']

faceNet=cv2.dnn.readNet(faceModel,faceProto)
ageNet=cv2.dnn.readNet(ageModel,ageProto)
genderNet=cv2.dnn.readNet(genderModel,genderProto)

# %%
def main_func(vid_path=''):
    ################
        def Realtime_Detection_func(Video_frame, Pretrain_face_detection_Model,cls_model):

            (height, width) = Video_frame.shape[:-1]
            Img_blob = cv2.dnn.blobFromImage(Video_frame, 1.0, (224, 224),(104.0, 177.0, 123.0))

            # pass the blob through the network and obtain the face detections
            Pretrain_face_detection_Model.setInput(Img_blob)
            face_identify = Pretrain_face_detection_Model.forward()
            print(face_identify.shape)

            # initialize our list of faces, their corresponding locations,
            # and the list of predictions from our face mask network
            faces_in_frame_lst = []
            faces_location_lst = []
            model_preds_lst = []

            for i in range(0, face_identify.shape[2]):

                conf_value = face_identify[0, 0, i, 2]
                if conf_value > 0.6:

                    Rectangle_box = face_identify[0, 0, i, 3:7] * np.array([width, height, width, height])
                    (starting_PointX, starting_PointY, ending_PointX, ending_PointY) = Rectangle_box.astype("int")
                    (starting_PointX, starting_PointY) = (max(0, starting_PointX), max(0, starting_PointY))
                    (ending_PointX, ending_PointY) = (min(width - 1, ending_PointX), min(height - 1, ending_PointY))
                    face_detect = vid_frm[starting_PointY:ending_PointY, starting_PointX:ending_PointX]
                    face_RGB = cv2.cvtColor(face_detect, cv2.COLOR_BGR2RGB)
                    face_Resize = cv2.resize(face_RGB, (224, 224))
                    face_to_array = img_to_array(face_Resize)
                    face_rescale = preprocess_input(face_to_array)

                    faces_in_frame_lst.append(face_rescale)
                    faces_location_lst.append((starting_PointX, starting_PointY, ending_PointX, ending_PointY))
                    
            if len(faces_in_frame_lst) > 0:

                faces_in_frame_lst = np.array(faces_in_frame_lst, dtype="float32")
                model_preds_lst = cls_model.predict(faces_in_frame_lst, batch_size=16)

            return (model_preds_lst, faces_location_lst)
        # loop over the frames from the video stream
        if vid_path != '':
            print("[INFO] starting video stream...")
            vid_stm = VideoStream(src=vid_path).start()
        elif vid_path == '':
            print("[INFO] starting live stream...")
            vid_stm = VideoStream(src=0).start()
        while True:

            vid_frm = vid_stm.read()
            vid_frm = imutils.resize(vid_frm, width=800)
            #=====
            
            padding=20
   
            resultImg,faceBoxes=highlightFace(faceNet,vid_frm)
            if not faceBoxes:
                print("No face detected")

            (model_preds_lst, faces_location_lst) = Realtime_Detection_func(vid_frm, Pretrain_face_detection_Model, cls_model)

            for (pred,Rectangle_box,faceBox) in zip(model_preds_lst, faces_location_lst,faceBoxes):
                (starting_PointX, starting_PointY, ending_PointX, ending_PointY) = Rectangle_box
                (mask_img, NoMask_img) = pred
                
                face=vid_frm[max(0,faceBox[1]-padding):
                           min(faceBox[3]+padding,vid_frm.shape[0]-1),max(0,faceBox[0]-padding)
                           :min(faceBox[2]+padding, vid_frm.shape[1]-1)]
                blob=cv2.dnn.blobFromImage(face, 1.0, (227,227), MODEL_MEAN_VALUES, swapRB=False)
                genderNet.setInput(blob)
                genderPreds=genderNet.forward()
                gender=genderList[genderPreds[0].argmax()]
                print(f'Gender: {gender}')

                ageNet.setInput(blob)
                agePreds=ageNet.forward()
                age=ageList[agePreds[0].argmax()]
                print(f'Age: {age[1:-1]} years')

                label = "Mask" if mask_img > NoMask_img else "No Mask"
                color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

                #label = "{}: {:.2f}%".format(label, max(mask_img, NoMask_img) * 100)

                cv2.putText(vid_frm, label+':'+f'   {gender}, {age}', (starting_PointX, starting_PointY - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
                cv2.rectangle(vid_frm, (starting_PointX, starting_PointY), (ending_PointX, ending_PointY), color, 2)

            cv2.imshow("Video Frame", vid_frm)
            key = cv2.waitKey(1) & 0xFF
            if key == ord("q"):
                break

        # do a bit of cleanup
        cv2.destroyAllWindows()
        vid_stm.stop()

# %%
import tkinter as tk
from tkinter import filedialog
import os

def main():
    # Function for opening the
    # file explorer window
    def browseFiles():
        filename = filedialog.askopenfilename(initialdir = "/",
                                            title = "Select a File",
                                            filetypes = (("Text files",
                                                            "*.mp4"),
                                                        ("all files",
                                                            "*.*")))
        # Change label contents
        label_file_explorer.configure(text="File Opened: "+filename)
        return(filename)

    # Create the root window
    window = tk.Tk()

    # Set window title
    window.title('Face Mask Detection')

    # Set window size
    window.geometry("300x300")

    # Set window background color
    window.config(bg='#1a1a1a')

    # Create a custom font
    custom_font = ('Arial', 12, 'bold')

    # Create a File Explorer label
    label_file_explorer = tk.Label(window,
                                text = "Face mask Detection using Tkinter",
                                width = 100, height = 4,
                                fg = "white",
                                font=custom_font,
                                padx=10, pady=10)

    button_explore = tk.Button(window,
                            text = "Browse Files",
                            command = browseFiles,
                            font=custom_font,
                            fg='#00ff7f',
                            padx=10, pady=10)

    button_live_stream=tk.Button(window,
                        text = "Live Stream",
                        command = main_func,
                        font=custom_font,
                        fg='#00ff7f',
                        padx=10, pady=10)

    button_video_stream=tk.Button(window,
                        text = "Video Stream",
                        command = lambda: main_func(browseFiles()),
                        font=custom_font,
                        fg='#00ff7f',
                        padx=10, pady=10)
        
    button_exit = tk.Button(window,
                        text = "Exit",
                        command = window.destroy,
                        font=custom_font,
                        fg='#ff0000',
                        padx=10, pady=10)

    button_live_stream.grid(column = 1,row = 4)

    button_video_stream.grid(column = 1,row = 5)

    button_exit.grid(column = 1,row = 6)

    # Add an image to the background
    #image_file = os.path.join(os.path.dirname(r'C:\Users\Ali Qaisar\Documents\FaceMask-Gender_Age_Detection_Prediction'), 'AI.jpg')
    #image = tk.PhotoImage(file=image_file)
    #label_background = tk.Label(window, image=image)
    #label_background.place(x=0, y=0, relwidth=1, relheight=1)

    # Let the window wait for any events
    window.mainloop()

# %%
if __name__ =="__main__":
    main()
# Out:
# [INFO] starting live stream...
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Gender: Male
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Male
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Gender: Female
# Age: 48-59 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Gender: Female
# Age: 48-59 years
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Female
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Male
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "A:\Anaconda\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Ali Qaisar\AppData\Local\Temp\ipykernel_8364\3351719818.py", line 53, in main_func
#     vid_frm = imutils.resize(vid_frm, width=800)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "A:\Anaconda\Lib\site-packages\imutils\convenience.py", line 69, in resize
#     (h, w) = image.shape[:2]
#              ^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'shape'
# [INFO] starting live stream...
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Gender: Female
# Age: 13-20 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Gender: Male
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Male
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 21-37 years
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Gender: Female
# Age: 48-59 years
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Gender: Male
# Age: 0-3 years
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Gender: Female
# Age: 0-3 years
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Gender: Female
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Gender: Female
# Age: 60-100 years
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Male
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Gender: Female
# Age: 38-47 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# Gender: Female
# Age: 48-59 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Gender: Female
# Age: 8-12 years
# Gender: Female
# Age: 48-59 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 8-12 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 8-12 years
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Male
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Female
# Age: 21-37 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Male
# Age: 13-20 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Gender: Female
# Age: 0-3 years
# Gender: Male
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Male
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Male
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Gender: Male
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Gender: Male
# Age: 13-20 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Male
# Age: 21-37 years
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Male
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Gender: Male
# Age: 0-3 years
# Gender: Male
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Female
# Age: 0-3 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Male
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Gender: Male
# Age: 0-3 years
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Female
# Age: 48-59 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Gender: Male
# Age: 13-20 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Gender: Male
# Age: 0-3 years
# Gender: Male
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Male
# Age: 21-37 years
# Gender: Male
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 8-12 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 0-3 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 60-100 years
# Gender: Female
# Age: 48-59 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Gender: Female
# Age: 4-7 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 60-100 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 21-37 years
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Female
# Age: 21-37 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Gender: Female
# Age: 0-3 years
# ...
# Gender: Female
# Age: 13-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Gender: Male
# Age: 4-7 years
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 38-47 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Gender: Female
# Age: 4-7 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Gender: Female
# Age: 0-3 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Gender: Female
# Age: 0-3 years
